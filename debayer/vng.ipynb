# %%
from astropy.io import fits
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %%
f = fits.open(r"D:\Astro\20220711-M13-OAG-Test\M13-Light\Light_ASIImg_90sec_Bin1_-0.3C_gain120_2022-07-10_232701_frame0001.fit")
img = f[0].data

# %%
# Out:
# dtype('uint16')

# %%
plt.imsave(r"C:\Users\anand\Desktop\output.png", img, dpi=300)

# %%
sobelx = cv2.Sobel(img, cv2.CV_16U, 1, 0, ksize=5)
sobely = cv2.Sobel(img, cv2.CV_16U, 0, 1, ksize=5)

# %%
plt.imshow(sobelx)

# %%
plt.imshow(sobely)
